# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import datetime as dt
# %matplotlib inline
import math

# %%
claims = pd.read_csv("C:/Data Sets/(Class 9-Python - Case Study)/3.Insurance_Claims/claims.csv")
cust = pd.read_csv("C:/Data Sets/(Class 9-Python - Case Study)/3.Insurance_Claims/cust_demographics.csv")

# %%
#Data Inspection
claims.info()
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 10 columns):
# claim_id               1100 non-null int64
# customer_id            1100 non-null int64
# incident_cause         1100 non-null object
# claim_date             1100 non-null object
# claim_area             1100 non-null object
# police_report          1100 non-null object
# claim_type             1100 non-null object
# claim_amount           1035 non-null object
# total_policy_claims    1090 non-null float64
# fraudulent             1100 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 86.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 6 columns):
# CUST_ID        1085 non-null int64
# gender         1085 non-null object
# DateOfBirth    1085 non-null object
# State          1085 non-null object
# Contact        1085 non-null object
# Segment        1085 non-null object
# dtypes: int64(1), object(5)
# memory usage: 51.0+ KB

# %%
claims
# Out:
#       claim_id  customer_id      incident_cause  claim_date claim_area  \
# 0     54004764     21868593        Driver error  11/27/2017       Auto
# 1     33985796     75740424               Crime  10/03/2018       Home
# 2     53522022     30308357  Other driver error  02/02/2018       Auto
# 3     13015401     47830476      Natural causes  06/17/2018       Auto
# 4     22890252     19269962               Crime  01/13/2018       Auto
# ...        ...          ...                 ...         ...        ...
# 1095  97727122     35951012  Other driver error  06/11/2017       Auto
# 1096  10247193     14818669      Natural causes  03/14/2018       Auto
# 1097  79807493     85322831  Other driver error  02/09/2018       Auto
# 1098  69299345     73449366        Other causes  03/21/2018       Auto
# 1099  58809728     43020876  Other driver error  06/04/2017       Auto
#
#      police_report           claim_type claim_amount  total_policy_claims  \
# 0               No        Material only        $2980                  1.0
# 1          Unknown        Material only        $2980                  3.0
# 2               No        Material only      $3369.5                  1.0
# 3               No        Material only        $1680                  1.0
# 4               No        Material only        $2680                  1.0
# ...            ...                  ...          ...                  ...
# 1095            No        Material only        $3059                  4.0
# 1096            No        Material only        $1520                  2.0
# 1097            No  Material and injury       $23575                  2.0
# 1098       Unknown  Material and injury       $25120                  1.0
# 1099           Yes  Material and injury       $36685                  3.0
#
#      fraudulent
# 0            No
# 1            No
# 2           Yes
# 3            No
# 4            No
# ...         ...
# 1095        Yes
# 1096         No
# 1097        Yes
# 1098         No
# 1099        Yes
#
# [1100 rows x 10 columns]

# %%
cust
# Out:
#        CUST_ID  gender DateOfBirth State       Contact   Segment
# 0     21868593  Female   12-Jan-79    VT  789-916-8172  Platinum
# 1     75740424  Female   13-Jan-70    ME  265-543-1264    Silver
# 2     30308357  Female   11-Mar-84    TN  798-631-4758    Silver
# 3     47830476  Female   01-May-86    MA  413-187-7945    Silver
# 4     19269962    Male   13-May-77    NV  956-871-8691      Gold
# ...        ...     ...         ...   ...           ...       ...
# 1080  79539873  Female   15-Mar-81    ND  459-425-4319  Platinum
# 1081  42364152  Female   07-Jul-96    ID  529-462-1635    Silver
# 1082  19888166    Male   11-Apr-90    WI  712-651-9613      Gold
# 1083  11256802  Female   22-Oct-64    LA  469-345-5617    Silver
# 1084  61575264    Male   12-Jul-95    WY  182-385-1392      Gold
#
# [1085 rows x 6 columns]

# %%
# Joining the tables
#Q1. Import claims_data.csv and cust_data.csv which is provided to you and combine the two datasets appropriately to create a 360-degree view of the data. Use the same for the subsequent questions.

cust_final = pd.merge(left= claims,right = cust , how= 'inner', left_on = 'customer_id' , right_on= 'CUST_ID' )

# %%
cust_final.iloc[1084:1100]

#Checked if the table is joined properly.
# Out:
#       claim_id  customer_id  incident_cause  claim_date claim_area  \
# 1084  63226031     61575264  Natural causes  03/16/2017       Auto
#
#      police_report     claim_type claim_amount  total_policy_claims  \
# 1084            No  Material only        $1490                  1.0
#
#      fraudulent   CUST_ID gender DateOfBirth State       Contact Segment
# 1084         No  61575264   Male   12-Jul-95    WY  182-385-1392    Gold

# %%
#2. Perform a data audit for the datatypes and find out if there are any mismatch within the current datatypes of the columns and their business significance.

cust_final.dtypes

#claim_date is object type. It should be datetime.
#claim_amount should be float or integer but is object
# Out:
# claim_id                 int64
# customer_id              int64
# incident_cause          object
# claim_date              object
# claim_area              object
# police_report           object
# claim_type              object
# claim_amount            object
# total_policy_claims    float64
# fraudulent              object
# CUST_ID                  int64
# gender                  object
# DateOfBirth             object
# State                   object
# Contact                 object
# Segment                 object
# dtype: object

# %%
#3. Convert the column claim_amount to numeric. Use the appropriate modules/attributes to remove the $ sign.

cust_final.claim_amount = cust_final.claim_amount.str.replace('$', '')
cust_final.claim_amount = pd.to_numeric(cust_final.claim_amount)

cust_final.claim_amount

#cust_final.claim_amount.astype('float64')
# Out:
# 0        2980.0
# 1        2980.0
# 2        3369.5
# 3        1950.0
# 4        1680.0
#          ...
# 1080     1770.0
# 1081     2800.0
# 1082    33080.0
# 1083     2840.0
# 1084     1490.0
# Name: claim_amount, Length: 1085, dtype: float64

# %%
#4. Of all the injury claims, some of them have gone unreported with the police. Create an alert flag (1,0) for all such claims.

a = cust_final[cust_final.claim_type =='Injury only']

# %%
cust_final['Alert Flag'] = cust_final[cust_final.claim_type =='Injury only'].police_report.map({'No':0, 'Unknown':1})

a
# Out:
#       claim_id  customer_id      incident_cause  claim_date claim_area  \
# 8     24050443     21831191  Other driver error  10/04/2017       Auto
# 18    67257404     18288638  Other driver error  04/24/2018       Auto
# 21     7809917     63916778        Other causes  07/22/2017       Auto
# 22    29205389     17004138      Natural causes  06/25/2017       Auto
# 23    19051665      9667764        Other causes  12/17/2017       Auto
# ...        ...          ...                 ...         ...        ...
# 1062  85546357     90217818  Other driver error  06/04/2017       Auto
# 1064  56358443     75934330      Natural causes  01/01/2017       Auto
# 1072  50800999     51669975        Other causes  09/19/2018       Home
# 1074  36599575     87596868        Driver error  10/09/2018       Auto
# 1082  22690595     19888166  Other driver error  05/15/2017       Auto
#
#      police_report   claim_type  claim_amount  total_policy_claims fraudulent  \
# 8               No  Injury only       38306.5                  3.0        Yes
# 18             Yes  Injury only       32560.0                  1.0         No
# 21              No  Injury only       17800.0                  1.0         No
# 22              No  Injury only       31380.0                  1.0         No
# 23             Yes  Injury only       36190.0                  1.0         No
# ...            ...          ...           ...                  ...        ...
# 1062            No  Injury only       37743.0                  1.0        Yes
# 1064           Yes  Injury only       20630.0                  1.0         No
# 1072           Yes  Injury only       38950.0                  1.0         No
# 1074       Unknown  Injury only       33330.0                  2.0         No
# 1082           Yes  Injury only       33080.0                  2.0         No
#
#        CUST_ID  gender DateOfBirth State       Contact   Segment
# 8     21831191    Male   17-May-77    NH  419-712-8513      Gold
# 18    18288638  Female   14-Jan-69    MI  314-135-1359  Platinum
# 21    63916778    Male   07-Sep-66    IL  146-157-4572  Platinum
# 22    17004138  Female   13-Aug-65    WA  436-354-4682    Silver
# 23     9667764  Female   10-Oct-79    SC  643-978-8251  Platinum
# ...        ...     ...         ...   ...           ...       ...
# 1062  90217818  Female   18-May-80    TN  891-651-8671      Gold
# 1064  75934330  Female   09-Oct-87    ME  951-941-3975  Platinum
# 1072  51669975  Female   05-Feb-88    ND  975-463-9541    Silver
# 1074  87596868    Male   18-Nov-61    AZ  573-396-3182    Silver
# 1082  19888166    Male   11-Apr-90    WI  712-651-9613      Gold
#
# [195 rows x 16 columns]

# %%
#5. One customer can claim for insurance more than once and in each claim,multiple categories of claims can be involved. However, customer ID should remain unique.

cust_final.customer_id[cust_final.customer_id.duplicated()].count()

#7 customer_id were duplicated.

cust_final.customer_id.drop_duplicates(inplace = True)
cust_final
# Out:
#       claim_id  customer_id      incident_cause  claim_date claim_area  \
# 0     54004764     21868593        Driver error  11/27/2017       Auto
# 1     33985796     75740424               Crime  10/03/2018       Home
# 2     53522022     30308357  Other driver error  02/02/2018       Auto
# 3     63017412     30308357        Driver error  04/04/2018       Auto
# 4     13015401     47830476      Natural causes  06/17/2018       Auto
# ...        ...          ...                 ...         ...        ...
# 1080  62020796     79539873  Other driver error  09/06/2018       Auto
# 1081  63269067     42364152        Other causes  05/09/2017       Home
# 1082  22690595     19888166  Other driver error  05/15/2017       Auto
# 1083  12376894     11256802  Other driver error  04/18/2017       Auto
# 1084  63226031     61575264      Natural causes  03/16/2017       Auto
#
#      police_report     claim_type  claim_amount  total_policy_claims  \
# 0               No  Material only        2980.0                  1.0
# 1          Unknown  Material only        2980.0                  3.0
# 2               No  Material only        3369.5                  1.0
# 3               No  Material only        1950.0                  6.0
# 4               No  Material only        1680.0                  1.0
# ...            ...            ...           ...                  ...
# 1080           Yes  Material only        1770.0                  1.0
# 1081            No  Material only        2800.0                  1.0
# 1082           Yes    Injury only       33080.0                  2.0
# 1083            No  Material only        2840.0                  4.0
# 1084            No  Material only        1490.0                  1.0
#
#      fraudulent   CUST_ID  gender DateOfBirth State       Contact   Segment  \
# 0            No  21868593  Female   12-Jan-79    VT  789-916-8172  Platinum
# 1            No  75740424  Female   13-Jan-70    ME  265-543-1264    Silver
# 2           Yes  30308357  Female   11-Mar-84    TN  798-631-4758    Silver
# 3            No  30308357  Female   11-Mar-84    TN  798-631-4758    Silver
# 4            No  47830476  Female   01-May-86    MA  413-187-7945    Silver
# ...         ...       ...     ...         ...   ...           ...       ...
# 1080         No  79539873  Female   15-Mar-81    ND  459-425-4319  Platinum
# 1081         No  42364152  Female   07-Jul-96    ID  529-462-1635    Silver
# 1082         No  19888166    Male   11-Apr-90    WI  712-651-9613      Gold
# 1083         No  11256802  Female   22-Oct-64    LA  469-345-5617    Silver
# 1084         No  61575264    Male   12-Jul-95    WY  182-385-1392      Gold
#
#       Alert Flag
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1080         NaN
# 1081         NaN
# 1082         NaN
# 1083         NaN
# 1084         NaN
#
# [1085 rows x 17 columns]

# %%
#6. Check for missing values and impute the missing values with an appropriate value. (mean for continuous and mode for categorical)

cust_final.info()
#There are certain missing values as seen from the info.
#Also some data types are wrong for example claim_date. Changing it to datetime.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1085 entries, 0 to 1084
# Data columns (total 17 columns):
# claim_id               1085 non-null int64
# customer_id            1085 non-null int64
# incident_cause         1085 non-null object
# claim_date             1085 non-null object
# claim_area             1085 non-null object
# police_report          1085 non-null object
# claim_type             1085 non-null object
# claim_amount           1020 non-null float64
# total_policy_claims    1075 non-null float64
# fraudulent             1085 non-null object
# CUST_ID                1085 non-null int64
# gender                 1085 non-null object
# DateOfBirth            1085 non-null object
# State                  1085 non-null object
# Contact                1085 non-null object
# Segment                1085 non-null object
# Alert Flag             125 non-null float64
# dtypes: float64(3), int64(3), object(11)
# memory usage: 152.6+ KB

# %%
cust_final.claim_date = pd.to_datetime(cust_final.claim_date)

# %%
cust_final.DateOfBirth = pd.to_datetime(cust_final.DateOfBirth)

# %%
#Missing Value Imputation as per the question. Separating numeric and object type data types.

# Missing value imputation for categorical and continuous variables
def missing_imputation(x, stats = 'mean'):
    if (x.dtypes == 'float64') | (x.dtypes == 'int64'):
        x = x.fillna(x.mean()) if stats == 'mean' else x.fillna(x.median())
    else:
        x = x.fillna(x.mode())
    return x

# %%
cust_numeric= cust_final.select_dtypes(['float64','int64'])
cust_object = cust_final.select_dtypes(['object','datetime64[ns]'])

# %%
cust_numeric = cust_numeric.apply(missing_imputation)
cust_object = cust_object.apply(missing_imputation)

#cust_cat.gender =  cust_cat.gender.fillna(cust_cat.gender.mode())

# %%
cust_final1 = pd.concat([cust_numeric,cust_object], axis = 1)

# %%
cust_final1
# Out:
#       claim_id  customer_id  claim_amount  total_policy_claims   CUST_ID  \
# 0     54004764     21868593        2980.0                  1.0  21868593
# 1     33985796     75740424        2980.0                  3.0  75740424
# 2     53522022     30308357        3369.5                  1.0  30308357
# 3     63017412     30308357        1950.0                  6.0  30308357
# 4     13015401     47830476        1680.0                  1.0  47830476
# ...        ...          ...           ...                  ...       ...
# 1080  62020796     79539873        1770.0                  1.0  79539873
# 1081  63269067     42364152        2800.0                  1.0  42364152
# 1082  22690595     19888166       33080.0                  2.0  19888166
# 1083  12376894     11256802        2840.0                  4.0  11256802
# 1084  63226031     61575264        1490.0                  1.0  61575264
#
#       Alert Flag      incident_cause claim_date claim_area police_report  \
# 0           0.52        Driver error 2017-11-27       Auto            No
# 1           0.52               Crime 2018-10-03       Home       Unknown
# 2           0.52  Other driver error 2018-02-02       Auto            No
# 3           0.52        Driver error 2018-04-04       Auto            No
# 4           0.52      Natural causes 2018-06-17       Auto            No
# ...          ...                 ...        ...        ...           ...
# 1080        0.52  Other driver error 2018-09-06       Auto           Yes
# 1081        0.52        Other causes 2017-05-09       Home            No
# 1082        0.52  Other driver error 2017-05-15       Auto           Yes
# 1083        0.52  Other driver error 2017-04-18       Auto            No
# 1084        0.52      Natural causes 2017-03-16       Auto            No
#
#          claim_type fraudulent  gender DateOfBirth State       Contact  \
# 0     Material only         No  Female  1979-01-12    VT  789-916-8172
# 1     Material only         No  Female  1970-01-13    ME  265-543-1264
# 2     Material only        Yes  Female  1984-03-11    TN  798-631-4758
# 3     Material only         No  Female  1984-03-11    TN  798-631-4758
# 4     Material only         No  Female  1986-05-01    MA  413-187-7945
# ...             ...        ...     ...         ...   ...           ...
# 1080  Material only         No  Female  1981-03-15    ND  459-425-4319
# 1081  Material only         No  Female  1996-07-07    ID  529-462-1635
# 1082    Injury only         No    Male  1990-04-11    WI  712-651-9613
# 1083  Material only         No  Female  2064-10-22    LA  469-345-5617
# 1084  Material only         No    Male  1995-07-12    WY  182-385-1392
#
#        Segment
# 0     Platinum
# 1       Silver
# 2       Silver
# 3       Silver
# 4       Silver
# ...        ...
# 1080  Platinum
# 1081    Silver
# 1082      Gold
# 1083    Silver
# 1084      Gold
#
# [1085 rows x 17 columns]

# %%
#7. Calculate the age of customers in years. Based on the age, categorize the customers according to the below criteria

#cust_final1['Age'] = pd.datetime.now().year - cust_final1.DateOfBirth

# %%
a = pd.to_datetime(cust_final1.DateOfBirth)
cust_final1['Year'] = a.dt.year

# %%
cust_final1.drop(columns = 'Age', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-13960ac3f4cc> in <module>
# ----> 1 cust_final1.drop(columns = 'Age', inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['Age'] not found in axis"

# %%
cust_final1['Age'] =  pd.datetime.now().year- a.dt.year

# %%
cust_final1['Age_group'] = pd.cut(cust_final1.Age, bins = [-50,0, 18, 30, 60,100], labels = ['Wrong Information','Children','Youth','Adult','Senior'] )

#We have one negative age which is wrong information so instead of null gave it the name Wrong Information.

# %%
#8. What is the average amount claimed by the customers from various segments?

cust_final1.pivot_table(values = 'claim_amount', index= 'claim_type', columns = 'incident_cause',aggfunc = np.mean).T
# Out:
# claim_type           Injury only  Material and injury  Material only
# incident_cause
# Crime               27846.227273         31549.642857    2578.693410
# Driver error        24062.409915         28868.601233    2938.503487
# Natural causes      26274.834198         26430.627684    2597.685480
# Other causes        25963.122627         27746.675968    2950.077614
# Other driver error  27414.065936         28075.690875    2607.397439

# %%
#9. What is the total claim amount based on incident cause for all the claims that have been done at least 20 days prior to 1st of October, 2018.

a = cust_final1.claim_date[cust_final1.claim_date > '2018-10-01']
b = a +  pd.DateOffset(days = 20)

cust_final1.claim_date[cust_final1.claim_date > '2018-10-01' ] 
cust_final1.pivot_table(index = b, values = 'claim_amount', aggfunc = np.sum)
# Out:
#              claim_amount
# claim_date
# 2018-10-23  187834.681373
# 2018-10-29  225007.500000
# 2018-11-05  119829.000000
# 2018-11-12  147078.362745
# 2018-11-19  120729.862745

# %%
#10. How many adults from TX, DE and AK claimed insurance for driver related issues and causes?

cust_final1[(cust_final1.Age_group == 'Adult') 
            & cust_final1.State.isin(['TX','DE','AK']) 
            & (cust_final1.incident_cause.isin(['Driver error','Other driver error']))]
# Out:
#       claim_id  customer_id  claim_amount  total_policy_claims   CUST_ID  \
# 101    4506676      2632562   1400.000000                  1.0   2632562
# 103   82144259     92752865  12467.681373                  1.0  92752865
# 147   26716331      3159546  17590.000000                  4.0   3159546
# 187   21550521     68772500   2320.000000                  1.0  68772500
# 188   69348631       154557  12467.681373                  1.0    154557
# 199   46572741     82415154  15240.000000                  1.0  82415154
# 246    7238381       684748   2920.000000                  2.0    684748
# 275   34621474     54094880   1529.500000                  1.0  54094880
# 277   93028492     62204138   2691.000000                  1.0  62204138
# 322   87329176     77510822  12467.681373                  2.0  77510822
# 376   92399694     92971195   1140.000000                  1.0  92971195
# 381      70068      4669941  29900.000000                  1.0   4669941
# 430   22577147     66433138  21447.500000                  2.0  66433138
# 453   99281527     32464636   2323.000000                  1.0  32464636
# 524    9124181     19796899  24667.500000                  1.0  19796899
# 551   86096444     65899365  34160.000000                  1.0  65899365
# 607   30280492     84147585   2380.000000                  1.0  84147585
# 608   78221963     84147585  14430.000000                  4.0  84147585
# 849   94983900     18282409  31020.000000                  2.0  18282409
# 926    7136079     29903212   2668.000000                  2.0  29903212
# 984   17396013     44050095  20458.500000                  1.0  44050095
# 1016  12612736     74787956  12467.681373                  1.0  74787956
#
#       Alert Flag      incident_cause claim_date claim_area police_report  \
# 101         0.52  Other driver error 2018-05-14       Home       Unknown
# 103         0.00        Driver error 2017-04-25       Auto            No
# 147         0.00  Other driver error 2017-04-25       Auto            No
# 187         0.52        Driver error 2018-08-30       Auto       Unknown
# 188         0.00        Driver error 2018-04-10       Auto            No
# 199         0.52  Other driver error 2017-06-11       Auto            No
# 246         0.52  Other driver error 2018-07-14       Auto            No
# 275         0.52  Other driver error 2017-02-17       Auto            No
# 277         0.52        Driver error 2017-10-31       Auto       Unknown
# 322         0.52  Other driver error 2018-10-30       Auto       Unknown
# 376         0.52  Other driver error 2018-09-26       Home            No
# 381         1.00        Driver error 2017-11-06       Auto       Unknown
# 430         0.52        Driver error 2017-02-23       Auto            No
# 453         0.52        Driver error 2017-10-31       Auto            No
# 524         0.52  Other driver error 2018-04-04       Auto           Yes
# 551         0.52        Driver error 2018-07-14       Auto            No
# 607         0.52        Driver error 2017-01-07       Auto       Unknown
# 608         0.52        Driver error 2018-04-10       Auto           Yes
# 849         0.00        Driver error 2017-08-11       Auto            No
# 926         0.52        Driver error 2018-06-17       Auto            No
# 984         0.52        Driver error 2017-03-22       Auto       Unknown
# 1016        0.52        Driver error 2017-09-14       Auto       Unknown
#
#                claim_type fraudulent  gender DateOfBirth State       Contact  \
# 101         Material only         No  Female  1985-12-14    AK  498-597-9658
# 103           Injury only         No    Male  1986-01-30    AK  143-219-5498
# 147           Injury only         No    Male  1987-10-20    TX  586-129-9752
# 187         Material only         No    Male  1989-11-10    TX  562-259-5432
# 188           Injury only        Yes  Female  1978-05-23    DE  962-879-1238
# 199   Material and injury         No  Female  1980-03-08    DE  578-942-1542
# 246         Material only         No    Male  1977-08-03    AK  613-385-2863
# 275         Material only        Yes    Male  1984-06-01    DE  568-481-7418
# 277         Material only        Yes  Female  1989-12-15    DE  471-934-4961
# 322         Material only         No  Female  1986-03-18    AK  436-934-7156
# 376         Material only         No    Male  1975-02-02    DE  892-173-4657
# 381           Injury only        Yes    Male  1982-08-03    AK  761-462-3458
# 430   Material and injury        Yes    Male  1978-06-27    TX  752-617-3867
# 453         Material only        Yes  Female  1988-08-25    DE  862-247-1496
# 524   Material and injury        Yes  Female  1975-12-17    TX  725-873-8239
# 551   Material and injury         No  Female  1973-07-25    TX  135-971-8567
# 607         Material only         No    Male  1972-10-18    AK  743-569-4783
# 608           Injury only         No    Male  1972-10-18    AK  743-569-4783
# 849           Injury only         No  Female  1973-09-29    AK  326-215-7361
# 926         Material only        Yes    Male  1989-12-16    DE  279-918-3268
# 984   Material and injury        Yes    Male  1977-06-04    DE  314-298-9257
# 1016        Material only         No    Male  1989-06-19    TX  679-514-5894
#
#        Segment  Year  Age Age_group
# 101   Platinum  1985   35     Adult
# 103     Silver  1986   34     Adult
# 147   Platinum  1987   33     Adult
# 187     Silver  1989   31     Adult
# 188   Platinum  1978   42     Adult
# 199   Platinum  1980   40     Adult
# 246       Gold  1977   43     Adult
# 275     Silver  1984   36     Adult
# 277   Platinum  1989   31     Adult
# 322     Silver  1986   34     Adult
# 376       Gold  1975   45     Adult
# 381   Platinum  1982   38     Adult
# 430       Gold  1978   42     Adult
# 453       Gold  1988   32     Adult
# 524       Gold  1975   45     Adult
# 551   Platinum  1973   47     Adult
# 607       Gold  1972   48     Adult
# 608       Gold  1972   48     Adult
# 849       Gold  1973   47     Adult
# 926   Platinum  1989   31     Adult
# 984   Platinum  1977   43     Adult
# 1016      Gold  1989   31     Adult

# %%
#11. Draw a pie chart between the aggregated value of claim amount based on gender and segment. Represent the claim amount as a percentage on the pie chart.

a = cust_final1.pivot_table(values = 'claim_amount', index = 'gender', aggfunc = np.sum )

a.round(2).loc['Female','claim_amount'] # 6381133.76 for Females
a.round(2).loc['Male','claim_amount'] # 7146300.53 for Males

labels = 'Female', 'Male'
sizes = [a.round(2).loc['Female','claim_amount'] ,a.round(2).loc['Male','claim_amount']]
colors = [ 'yellowgreen', 'lightskyblue']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
#12 Among males and females, which gender had claimed the most for any type of driver related issues? E.g. This metric can be compared using a bar chart

a = cust_final1[cust_final1.incident_cause.isin(['Driver error',  'Other driver error'])].gender == 'Female'

b = cust_final1[cust_final1.incident_cause.isin(['Driver error',  'Other driver error'])].gender == 'Male'

a[a].count() #222 Count Female

b[b].count() #284 Count Male
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
gender = ['Female','Male']
count = [a[a].count(),b[b].count() ]
ax.bar(gender, count, color = 'G', width = 0.9)
plt.show()
# Out:
# C:\Users\shaur\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.

# %%
cust_final1.Age_group.unique()
# Out:
# [Adult, Youth, Wrong Information]
# Categories (3, object): [Wrong Information < Youth < Adult]

# %%
#13 Which age group had the maximum fraudulent policy claims? Visualize it on a bar chart.

a = cust_final1[cust_final1.fraudulent == 'Yes'].Age_group == 'Adult'
b = cust_final1[cust_final1.fraudulent == 'Yes'].Age_group == 'Youth'
c = cust_final1[cust_final1.fraudulent == 'Yes'].Age_group == 'Wrong Information'

a[a].count() #119 for Adults
b[b].count() #59 for Youth
c[c].count() #69 for Wrong Information

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
age = ['Adults','Youth','Wrong Information']
count = [a[a].count(),b[b].count(), c[c].count()]
ax.bar(age, count, width = 0.9, color = 'R')
plt.show()
# Out:
# C:\Users\shaur\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   from ipykernel import kernelapp as app

# %%
# 14. Visualize the monthly trend of the total amount that has been claimed by the customers. Ensure that on the “month” axis, the month is in a chronological order not alphabetical order.

a = pd.to_datetime(cust_final1.DateOfBirth)
cust_final1['Month'] = a.dt.month

b = cust_final1.pivot_table(index= 'Month', values = 'claim_amount', aggfunc = np.sum).round(2)

b.unstack('Month').plot(kind='bar', color = 'orange')
plt.show()

# %%
#15. What is the average claim amount for gender and age categories and suitably represent the above using a facetted bar chart, one facet that represents fraudulent claims and the other for non-fraudulent claims

a = cust_final1[cust_final1.fraudulent == 'No'] #No Fraud
b = cust_final1[cust_final1.fraudulent =='Yes'] #Fraud

c = a.pivot_table(values = 'claim_amount', index = 'Age_group',columns = ['fraudulent','gender'], aggfunc = np.mean )
d = b.pivot_table(values = 'claim_amount', index = 'Age_group', columns = ['fraudulent','gender'], aggfunc = np.mean )

c.plot(kind='bar')

plt.show()

d.plot(kind = 'bar')

plt.show()

# %%
#16. Is there any similarity in the amount claimed by males and females?

a = cust_final1[cust_final1.gender == 'Female']
b = cust_final1[cust_final1.gender == 'Male']

#a.claim_amount
#b.claim_amount.iloc[1:530] has been used to equal the records for males and females for pearson test.
#The amount claimed is slightly corelated.
stats.pearsonr(a.claim_amount, b.claim_amount.iloc[1:530])
stats.f_oneway(a.claim_amount, b.claim_amount.iloc[1:530])
stats.ttest_rel(a.claim_amount, b.claim_amount.iloc[1:530])
#The means of the insurance amount are similiar which can be said with 95% confidence.
#Also, the variances of the two groups are similar as the null hypothesis is not rejected which can be said with 95% confidence.
# Out:
# Ttest_relResult(statistic=-1.1231369855206668, pvalue=0.2618897395613942)

# %%
#17. Is there any relationship between age category and segment?

a = pd.crosstab(index = cust_final1.claim_type, columns = cust_final1.Age_group)
#Chi square test for categorical variables

stats.chi2_contingency(observed = a)
# Out:
# (9.4303913279819,
#  0.05119736923368133,
#  4,
#  array([[ 49.96313364,  49.78341014,  95.25345622],
#         [ 60.72442396,  60.50599078, 115.76958525],
#         [167.3124424 , 166.71059908, 318.97695853]]))

# %% [markdown]
# p value is high so we will not reject the null hypothesis. As per the null hypothesis, They are independent variables and do not directly corelate with each other categorically. We can be 99% confident about the same.

# %%
#18. The current year has shown a significant rise in claim amounts as compared to 2016-17 fiscal average which was $10,000.

a = cust_final1[cust_final1.claim_date.dt.year == 2017]
b = cust_final1[cust_final1.claim_date.dt.year == 2018]

a.claim_amount.sum() #7341975.12254902
a.claim_amount.mean() #12277.55037215556

b.claim_amount.sum() #6185459.166666667
b.claim_amount.mean() #12701.14818617386

#2017 had a higher claim amount compared to 2018. But the fiscal average of 2018 was slightly more than 2017.
# Out:
# 12701.14818617386

# %%
#19. Is there any difference between age groups and insurance claims?
#Comparison between categorical and continous variable.
stats.spearmanr(cust_final1.total_policy_claims,cust_final1.Age_group)
#The relationship is slightly correlated and is inversly proportional.
# Out:
# SpearmanrResult(correlation=-0.004037211988247131, pvalue=0.8943275553952107)

# %%
#20. Is there any relationship between total number of policy claims and the claimed amount?

stats.f_oneway(cust_final1.claim_amount, cust_final1.total_policy_claims)
stats.pearsonr(cust_final1.claim_amount, cust_final1.total_policy_claims)

#p value is very low and therefore the variances of both groups are different by ANOVA testing. 
#The relationship is slightly correlated and is inversly proportional.
# Out:
# (-0.01744856239346897, 0.5658830110326771)
